# %%
import torch
from torch import nn
from torch.nn import functional as F
from matplotlib import pyplot as plt
import random
from tqdm import trange

# %%
DEV = "cuda:0" if torch.cuda.is_available() else "cpu"
DEV = torch.device(DEV)
DEV
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Load data

# %%
# !wget https://raw.githubusercontent.com/ncarkaci/TDKDictionaryCrawler/master/ortak_kelimeler.txt
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open("ortak_kelimeler.txt", encoding='utf-8') as f:
    text = f.read()

# %%
words = text.split("\n")

# %%
long_text = text.replace("\n","")
ids = list(set(long_text))
len(ids)
# Out:
# 29

# %%
ordinal_char_pairs = sorted([(ord(c),c) for c in ids])
ordinal_char_pairs
# Out:
# [(97, 'a'),
#  (98, 'b'),
#  (99, 'c'),
#  (100, 'd'),
#  (101, 'e'),
#  (102, 'f'),
#  (103, 'g'),
#  (104, 'h'),
#  (105, 'i'),
#  (106, 'j'),
#  (107, 'k'),
#  (108, 'l'),
#  (109, 'm'),
#  (110, 'n'),
#  (111, 'o'),
#  (112, 'p'),
#  (114, 'r'),
#  (115, 's'),
#  (116, 't'),
#  (117, 'u'),
#  (118, 'v'),
#  (121, 'y'),
#  (122, 'z'),
#  (231, 'ç'),
#  (246, 'ö'),
#  (252, 'ü'),
#  (287, 'ğ'),
#  (305, 'ı'),
#  (351, 'ş')]

# %%
len(ordinal_char_pairs)
# Out:
# 29

# %% [markdown]
# ## Encode & Decode Functions

# %%
ctoi = {c:i for i,(o,c) in enumerate(ordinal_char_pairs)}
itoc =  {i:c for i,(o,c) in enumerate(ordinal_char_pairs)}

# %%
ctoi['.']=len(ctoi)
itoc[len(itoc)]='.'

# %%
def encode(input:str):
    return [ctoi[c] for c in input]

def decode(ids):
    return "".join([itoc[i] for i in ids])

# %%
assert decode(encode("zemberek"))=='zemberek'

# %% [markdown]
# ## Helpers

# %%
def plot_training_loss(nn, aggregate = 50):
    fig, axs = plt.subplots(1, 2, figsize=(20, 10))

    losses = nn.losses
    n = (len(losses) // aggregate)*aggregate
    losses = torch.tensor(losses[:n]).view(-1,aggregate).mean(1)

    val_losses = nn.val_losses
    n = (len(val_losses) // aggregate)*aggregate
    val_losses = torch.tensor(val_losses[:n]).view(-1,aggregate).mean(1)

    axs[0].plot(losses, label="Neural net train loss")
    axs[0].plot(val_losses, label="Neural net val loss")
    axs[0].set_title('Losses')
    axs[0].legend()

    axs[1].plot([g[1] for g in nn.grads], label="Max")
    axs[1].plot([g[0] for g in nn.grads], label="Min")
    axs[1].plot([g[2] for g in nn.grads], label="Mean")
    axs[1].plot([g[3] for g in nn.grads], label="Std.")
    axs[1].set_title('Gradients')
    axs[1].legend()

    plt.show()

# %% [markdown]
# ## Prepare Training Data

# %%
random.seed(13)
random.shuffle(words)

long_text = "."+".".join([w for w in words])+"."

n = len(long_text)
n1 = int(n*0.8)
n2 = int(n*0.9)

# %%
data = torch.tensor(encode(long_text), dtype=torch.long)

# %% [markdown]
# ## Train

# %%
class Trainer:
    def __init__(self, batch_size, block_size) -> None:
        
        self.batch_size = batch_size
        self.block_size = block_size

        # for logging
        self.losses = []
        self.val_losses = []
        self.grads = []    

    def train(self, nn:nn.Module, train_data, eval_data=None, lr=0.1, threshold=None, steps=1001, print_steps=10):
        if steps>1:
            print(f"Model has {sum([p.nelement() for p in nn.parameters()])} parameters!")
            print(f"Using {len(train_data)} samples")

        # set default loss value to zero
        loss = val_loss = torch.zeros((1))[0]

        # training loop
        for i in range(steps):
            bxs, bys = self.get_batch(train_data)

            # FORWARD
            logits = nn(bxs)

            B,T,C = logits.shape
            logits = logits.view(B*T,C)
            bys = bys.view(B*T)
            # loss: negative log likelihood
            loss = F.cross_entropy(logits, bys)
            
            # backward
            nn.zero_grad()
            loss.backward()

            if threshold and i > threshold:
                lr = lr * 0.5
                 
            # update weights
            for p in nn.parameters():
                p.data -= lr * p.grad

            # log validation loss
            if eval_data is not None:
                val_loss = self.evaluate(nn, eval_data)

            # report losses
            if steps>1 and i % print_steps == 0:
                print(f"Step {i} | loss: {loss.item():.4f} | val loss: {val_loss.item():.4f}")

            _params = list(nn.parameters())
            # logging
            self.losses.append(loss.item())
            self.grads.append([
                min([p.grad.min().item() for p in _params]),
                max([p.grad.max().item() for p in _params]),
                sum([p.grad.mean().item() for p in _params])/len(_params),
                sum([p.grad.std().item() for p in _params])/len(_params)
            ]
            )

        if steps>1:
            print(f"loss: {loss.item():.4f} validation loss: {val_loss.item():.4f}")

        pass

    @torch.no_grad()
    def evaluate(self, nn, data):
        nn.train(False) # eval mode
        
        val_bxs, val_bys = self.get_batch(data)
        val_logits = nn(val_bxs)
        
        B,T,C = val_logits.shape
        val_logits = val_logits.view(B*T,C)
        val_bys = val_bys.view(B*T)
        
        val_loss = F.cross_entropy(val_logits, val_bys)
                    
        self.val_losses.append(val_loss.item())
        
        nn.train(True) # back to train mode

        return val_loss

    def get_batch(self, data):
        ix = torch.randint(len(data)-self.block_size, (self.batch_size  if self.batch_size else len(data),))

        x = torch.stack([data[i:i+self.block_size] for i in ix])
        y = torch.stack([data[i+1:i+self.block_size+1] for i in ix])

        x, y = x.to(DEV), y.to(DEV)
        return x, y

# %%
def generate(nn, block_size):
    reverse_offset = -block_size
    n_start_chars = block_size

    chars = torch.tensor([ctoi['.']]*n_start_chars, device=DEV).view(1,-1)

    while True:
        input = chars[:,reverse_offset:]
        logits = nn(input)
        probs = F.softmax(logits, dim=-1)
        assert probs.shape == (1, block_size, 30), f"{probs.shape=}"

        probs_in = probs[0, -1, :]
        next_char = torch.multinomial(probs_in, 1, replacement=True)

        if next_char.item() == ctoi['.']:
            return decode(list(chars.cpu()[0].numpy())[n_start_chars:])
        
        chars = torch.concat((chars, next_char.view(1, -1)), dim=-1)

# %%
def lr_search(nn, data, block_size, steps=1001):
        lre = torch.linspace(-3, 0, steps)
        lrs = 10**lre

        lri = []
        trainer = Trainer(block_size=block_size, batch_size=1)
        for i in trange(steps):
            lr = lrs[i]
            
            trainer.train(nn, data, lr = lr, steps=1)
            
            lri.append(lre[i])

        fig, ax = plt.subplots(1, 1, figsize=(20, 10))
        ax.plot(lri[::20], torch.tensor(trainer.losses).view(-1,20).mean(1), label="average loss")
        ax.plot(lri, trainer.losses, label="loss")
        ax.legend()

        plt.show()

# %%
class FeedForward(nn.Module):
    """a simple layer followed by a non-linearity"""

    def __init__(self, n_embd = 384, dropout=0.2) -> None:
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),  # projection layer
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)


class MultiHead(nn.Module):
    def __init__(self, n_embd, num_heads, head_size, block_size, dropout=0.2):
        super().__init__()
                                        
        self.heads = nn.ModuleList([Head(n_embd, head_size, block_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        heads = [h(x) for h in self.heads]
        out = torch.cat(heads, dim=-1)
        prj = self.proj(out)
        return self.dropout(prj)


class Head(nn.Module):
    """one head self attention"""

    def __init__(self, n_embd, head_size, block_size, dropout=0.2) -> None:
        super().__init__()

        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer('tril', torch.tril(
            torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout1d(dropout)

    def forward(self, x):
        B, T, C = x.shape

        k = self.key(x)  # (B,T,C)
        q = self.query(x)  # (B,T,C)

        # (B,T,C) @ (B,C,T) ---> (B,T,T)
        wei = q @ k.transpose(-2, -1) * C ** -0.5  # (B,T,T)

        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)  # (B,T,T)
        wei = self.dropout(wei)
        # perform weighted aggregation of the values
        v = self.value(x)  # (B,T,C)
        out = wei @ v  # (B,T,T) @ (B,T,C) ---> (B,T,C)

        return out


class Block(nn.Module):
    """ Transformer block: communication followed by computation"""

    def __init__(self, n_embd, n_head, block_size) -> None:
        super().__init__()

        head_size = n_embd // n_head
        self.sa = MultiHead(n_embd, n_head, head_size, block_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class AttentionLm(nn.Module):
    def __init__(self, vocab_size, n_embd, block_size, n_head, n_layer):
        super().__init__()

        self.vocab_size = vocab_size
        self.block_size = block_size
        
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        self.blocks = nn.Sequential(*[ Block(n_embd, n_head=n_head, block_size=block_size) for _ in range(n_layer) ])

        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        assert T == self.block_size

        tok_emb = self.token_embedding_table(idx)  # (B,T,C)
        pos_emb = self.position_embedding_table(
            torch.arange(T, device=DEV))  # (T,C)

        x = tok_emb + pos_emb  # (B,T,C)
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)  # (B,T,vocab_size)

        assert logits.shape == (B, T, self.vocab_size)

        if targets is None:
            return logits
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)

            return logits

# %%
# %%time

torch.manual_seed(13)

block_size = 32
n_embd = 9

nn4 = AttentionLm(vocab_size=30, n_embd=n_embd, block_size=block_size, n_head=3, n_layer=1)
nn4.to(DEV)

lr_search(nn4, data[:3000], block_size=block_size, steps=1020)
# Out:
# 100%|██████████| 1020/1020 [00:21<00:00, 47.73it/s]
# CPU times: total: 21.4 s
# Wall time: 21.6 s

# %% [markdown]
# Right learning rate is not obvious from the chart above.

# %%
# %%time

torch.manual_seed(13)

block_size = 32
batch_size = 1024
n_embd = 16
attention_lm = AttentionLm(30, n_embd, block_size, n_head=4, n_layer=1)
attention_lm.to(DEV)

trainer = Trainer(batch_size=batch_size, block_size=block_size)
trainer.train(attention_lm, data[:n1], data[n1:n2], lr=0.3, steps=1000)
# Out:
# Model has 4766 parameters!
# Using 293663 samples
# Step 0 | loss: 3.5932 | val loss: 3.5486
# Step 10 | loss: 3.2613 | val loss: 3.2289
# Step 20 | loss: 3.0927 | val loss: 3.0792
# Step 30 | loss: 3.0237 | val loss: 3.0154
# Step 40 | loss: 2.9974 | val loss: 2.9895
# Step 50 | loss: 2.9633 | val loss: 2.9657
# Step 60 | loss: 2.9638 | val loss: 2.9364
# Step 70 | loss: 2.9404 | val loss: 2.9331
# Step 80 | loss: 2.9298 | val loss: 2.9237
# Step 90 | loss: 2.9134 | val loss: 2.9110
# Step 100 | loss: 2.8974 | val loss: 2.8945
# Step 110 | loss: 2.8995 | val loss: 2.8936
# Step 120 | loss: 2.8862 | val loss: 2.8789
# Step 130 | loss: 2.8806 | val loss: 2.8657
# Step 140 | loss: 2.8711 | val loss: 2.8639
# Step 150 | loss: 2.8566 | val loss: 2.8508
# Step 160 | loss: 2.8486 | val loss: 2.8449
# Step 170 | loss: 2.8442 | val loss: 2.8438
# Step 180 | loss: 2.8335 | val loss: 2.8210
# Step 190 | loss: 2.8248 | val loss: 2.8115
# Step 200 | loss: 2.8104 | val loss: 2.8058
# Step 210 | loss: 2.8047 | val loss: 2.7916
# Step 220 | loss: 2.7892 | val loss: 2.7828
# Step 230 | loss: 2.7817 | val loss: 2.7869
# Step 240 | loss: 2.7739 | val loss: 2.7701
# Step 250 | loss: 2.7686 | val loss: 2.7632
# Step 260 | loss: 2.7522 | val loss: 2.7499
# Step 270 | loss: 2.7400 | val loss: 2.7516
# Step 280 | loss: 2.7425 | val loss: 2.7450
# Step 290 | loss: 2.7214 | val loss: 2.7259
# Step 300 | loss: 2.7294 | val loss: 2.7206
# Step 310 | loss: 2.7265 | val loss: 2.7162
# Step 320 | loss: 2.7097 | val loss: 2.7015
# Step 330 | loss: 2.7164 | val loss: 2.7068
# Step 340 | loss: 2.7101 | val loss: 2.7027
# Step 350 | loss: 2.6981 | val loss: 2.6901
# Step 360 | loss: 2.6966 | val loss: 2.6929
# Step 370 | loss: 2.6847 | val loss: 2.6952
# Step 380 | loss: 2.6935 | val loss: 2.6824
# Step 390 | loss: 2.6815 | val loss: 2.6833
# Step 400 | loss: 2.6800 | val loss: 2.6761
# Step 410 | loss: 2.6763 | val loss: 2.6624
# Step 420 | loss: 2.6801 | val loss: 2.6744
# Step 430 | loss: 2.6729 | val loss: 2.6735
# Step 440 | loss: 2.6670 | val loss: 2.6592
# Step 450 | loss: 2.6729 | val loss: 2.6599
# Step 460 | loss: 2.6609 | val loss: 2.6715
# Step 470 | loss: 2.6619 | val loss: 2.6674
# Step 480 | loss: 2.6644 | val loss: 2.6632
# Step 490 | loss: 2.6559 | val loss: 2.6411
# Step 500 | loss: 2.6632 | val loss: 2.6477
# Step 510 | loss: 2.6539 | val loss: 2.6519
# Step 520 | loss: 2.6605 | val loss: 2.6556
# Step 530 | loss: 2.6484 | val loss: 2.6460
# Step 540 | loss: 2.6472 | val loss: 2.6444
# Step 550 | loss: 2.6434 | val loss: 2.6458
# Step 560 | loss: 2.6441 | val loss: 2.6372
# Step 570 | loss: 2.6368 | val loss: 2.6384
# Step 580 | loss: 2.6531 | val loss: 2.6317
# Step 590 | loss: 2.6388 | val loss: 2.6343
# Step 600 | loss: 2.6462 | val loss: 2.6296
# Step 610 | loss: 2.6429 | val loss: 2.6363
# Step 620 | loss: 2.6383 | val loss: 2.6362
# Step 630 | loss: 2.6331 | val loss: 2.6378
# Step 640 | loss: 2.6287 | val loss: 2.6311
# Step 650 | loss: 2.6397 | val loss: 2.6302
# Step 660 | loss: 2.6323 | val loss: 2.6255
# Step 670 | loss: 2.6310 | val loss: 2.6168
# Step 680 | loss: 2.6353 | val loss: 2.6312
# Step 690 | loss: 2.6228 | val loss: 2.6167
# Step 700 | loss: 2.6250 | val loss: 2.6283
# Step 710 | loss: 2.6249 | val loss: 2.6160
# Step 720 | loss: 2.6386 | val loss: 2.6251
# Step 730 | loss: 2.6224 | val loss: 2.6226
# Step 740 | loss: 2.6357 | val loss: 2.6204
# Step 750 | loss: 2.6176 | val loss: 2.6144
# Step 760 | loss: 2.6194 | val loss: 2.6194
# Step 770 | loss: 2.6263 | val loss: 2.6182
# Step 780 | loss: 2.6238 | val loss: 2.6157
# Step 790 | loss: 2.6098 | val loss: 2.6228
# Step 800 | loss: 2.6219 | val loss: 2.6131
# Step 810 | loss: 2.6159 | val loss: 2.6153
# Step 820 | loss: 2.6208 | val loss: 2.6247
# Step 830 | loss: 2.6188 | val loss: 2.6051
# Step 840 | loss: 2.6139 | val loss: 2.6147
# Step 850 | loss: 2.6199 | val loss: 2.6082
# Step 860 | loss: 2.6113 | val loss: 2.6157
# Step 870 | loss: 2.6143 | val loss: 2.6044
# Step 880 | loss: 2.6109 | val loss: 2.6051
# Step 890 | loss: 2.6088 | val loss: 2.6056
# Step 900 | loss: 2.6051 | val loss: 2.6123
# Step 910 | loss: 2.6132 | val loss: 2.6040
# Step 920 | loss: 2.6169 | val loss: 2.6014
# Step 930 | loss: 2.6085 | val loss: 2.6087
# Step 940 | loss: 2.6139 | val loss: 2.6138
# Step 950 | loss: 2.6163 | val loss: 2.5999
# Step 960 | loss: 2.6072 | val loss: 2.6075
# Step 970 | loss: 2.6019 | val loss: 2.5903
# Step 980 | loss: 2.6077 | val loss: 2.6100
# Step 990 | loss: 2.6042 | val loss: 2.5994
# loss: 2.5999 validation loss: 2.5985
# CPU times: total: 3min 3s
# Wall time: 3min 5s

# %%
plot_training_loss(trainer)
